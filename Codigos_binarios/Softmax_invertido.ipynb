# %%
import tensorflow as tf
from tensorflow import keras
from keras import datasets, layers, models
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import precision_score, recall_score
import numpy as np
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import random
import os

# %%
dataset_dir = '/Users/MarcelM/Documents/GitHub/LungsXray-FP/data/raw/SOFTMAX'

# %%
image_size = (150, 150)
batch_size = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2,
    rotation_range=15,  # Nueva técnica: rotación
    width_shift_range=0.1,  # Nueva técnica: desplazamiento horizontal
    height_shift_range=0.1,  # Nueva técnica: desplazamiento vertical
)
train_generator = train_datagen.flow_from_directory(
    dataset_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)
validation_generator = train_datagen.flow_from_directory(
    dataset_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 5266 images belonging to 4 classes.
# Found 1315 images belonging to 4 classes.

# %%
num_classes = len(train_generator.class_indices)
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', input_shape=(image_size[0], image_size[1], 3)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),  # Reducir las neuronas aquí también
    tf.keras.layers.Dropout(0.5),  # Mantener el Dropout para reducir el sobreajuste
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
epochs = 10

history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator
)
# Out:
# Epoch 1/10
# 165/165 [==============================] - 353s 2s/step - loss: 1.0335 - accuracy: 0.5517 - val_loss: 0.7389 - val_accuracy: 0.6989
# Epoch 2/10
# 165/165 [==============================] - 338s 2s/step - loss: 0.7503 - accuracy: 0.7058 - val_loss: 0.6146 - val_accuracy: 0.7650
# Epoch 3/10
# 165/165 [==============================] - 337s 2s/step - loss: 0.6641 - accuracy: 0.7440 - val_loss: 0.6057 - val_accuracy: 0.7795
# Epoch 4/10
# 165/165 [==============================] - 336s 2s/step - loss: 0.6081 - accuracy: 0.7683 - val_loss: 0.5560 - val_accuracy: 0.7894
# Epoch 5/10
# 165/165 [==============================] - 320s 2s/step - loss: 0.5655 - accuracy: 0.7862 - val_loss: 0.4813 - val_accuracy: 0.8129
# Epoch 6/10
# 165/165 [==============================] - 345s 2s/step - loss: 0.5384 - accuracy: 0.8029 - val_loss: 0.4705 - val_accuracy: 0.8243
# Epoch 7/10
# 165/165 [==============================] - 343s 2s/step - loss: 0.5036 - accuracy: 0.8141 - val_loss: 0.4558 - val_accuracy: 0.8342
# Epoch 8/10
# 165/165 [==============================] - 345s 2s/step - loss: 0.5396 - accuracy: 0.7983 - val_loss: 0.5571 - val_accuracy: 0.7703
# Epoch 9/10
# 165/165 [==============================] - 361s 2s/step - loss: 0.5297 - accuracy: 0.8035 - val_loss: 0.4447 - val_accuracy: 0.8266
# Epoch 10/10
# 165/165 [==============================] - 320s 2s/step - loss: 0.4967 - accuracy: 0.8099 - val_loss: 0.4023 - val_accuracy: 0.8494

# %%
test_loss, test_acc = model.evaluate(validation_generator, verbose=2)
print('\nExactitud en el conjunto de validación:', test_acc)
# Out:
# 42/42 - 67s - loss: 0.4060 - accuracy: 0.8471 - 67s/epoch - 2s/step
#
# Exactitud en el conjunto de validación: 0.8471482992172241

# %%
model.save('modelo_softmax_invertido.keras')

# %%
model = load_model('/Users/MarcelM/Documents/GitHub/LungsXray-FP/models/modelo_softmax_invertido.keras')  # Ajusta el nombre de tu modelo

# Preprocesamiento de datos para el conjunto de prueba
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    dataset_dir,
    target_size=(150, 150),
    batch_size=32,
    class_mode='categorical',  # Ajusta si tu modelo espera etiquetas categóricas
    shuffle=False
)

# Obtener las predicciones del modelo para el conjunto de prueba
predictions = model.predict(test_generator)

# Convertir las predicciones a clases (si es necesario)
predicted_classes = np.argmax(predictions, axis=1)

# Obtener las etiquetas verdaderas
true_classes = test_generator.classes

# Calcular la precisión y el recall por clase
classification_rep = classification_report(true_classes, predicted_classes)
accuracy = accuracy_score(true_classes, predicted_classes)
conf_matrix = confusion_matrix(true_classes, predicted_classes)

print("Informe de clasificación:")
print(classification_rep)

print("Exactitud general:")
print(accuracy)

print("Matriz de confusión:")
print(conf_matrix)
# Out:
# Found 6581 images belonging to 4 classes.
# 206/206 [==============================] - 212s 1s/step
# Informe de clasificación:
#               precision    recall  f1-score   support
#
#            0       0.95      0.82      0.88      1589
#            1       0.85      0.93      0.89      1341
#            2       0.95      0.92      0.93      2616
#            3       0.80      0.95      0.87      1035
#
#     accuracy                           0.90      6581
#    macro avg       0.89      0.90      0.89      6581
# weighted avg       0.91      0.90      0.90      6581
#
# Exactitud general:
# 0.9012308159854125
# Matriz de confusión:
# [[1309   16   62  202]
#  [  10 1246   58   27]
#  [   9  192 2396   19]
#  [  43    5    7  980]]

# %%
from tensorflow.keras.utils import img_to_array, load_img

# Lista de carpetas en el directorio
folders = os.listdir(dataset_dir)

# Modelo preentrenado
model = load_model('/Users/MarcelM/Documents/GitHub/LungsXray-FP/models/modelo_softmax_invertido.keras')

# Número de imágenes a seleccionar por carpeta
num_images_por_carpeta = 25

# Crear un diccionario que mapea índices a nombres de carpetas
index_to_folder = {i: folder for i, folder in enumerate(folders)}

# Iterar sobre cada carpeta
for folder in folders:
    folder_path = os.path.join(dataset_dir, folder)
    
    # Lista de archivos en la carpeta
    files = os.listdir(folder_path)
    
    # Seleccionar aleatoriamente 25 imágenes
    selected_files = random.sample(files, num_images_por_carpeta)
    
    # Iterar sobre cada imagen seleccionada
    for file in selected_files:
        file_path = os.path.join(folder_path, file)
        
        # Cargar la imagen y preprocesarla
        img = load_img(file_path, target_size=(150, 150))
        img_array = img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0)
        img_array /= 255.0  # Normalizar
        
        # Hacer la predicción con el modelo
        prediction = model.predict(img_array)
        
        # Obtener la clase predicha
        predicted_class = np.argmax(prediction)
        
        # Obtener el nombre de la carpeta asociada a la clase predicha
        predicted_folder = index_to_folder[predicted_class]
        
        # Mostrar resultados
        print(f"Imagen: {file}, Carpeta Real: {folder}, Carpeta Predicha: {predicted_folder}")
# Out:
# 1/1 [==============================] - 0s 177ms/step
# Imagen: Tuberculosis-412.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 29ms/step
# Imagen: Tuberculosis-272.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 27ms/step
# Imagen: Tuberculosis-325.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 30ms/step
# Imagen: Tuberculosis-559.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 29ms/step
# Imagen: CHNCXR_0403_1.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 31ms/step
# Imagen: CHNCXR_0557_1.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 35ms/step
# Imagen: CHNCXR_0654_1.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 29ms/step
# Imagen: Tuberculosis-94.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 28ms/step
# Imagen: Tuberculosis-304.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 38ms/step
# Imagen: Tuberculosis-389.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 28ms/step
# Imagen: CHNCXR_0329_1.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 33ms/step
# Imagen: Tuberculosis-591.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 28ms/step
# Imagen: Tuberculosis-430.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 31ms/step
# Imagen: Tuberculosis-486.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 29ms/step
# Imagen: Tuberculosis-619.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 32ms/step
# Imagen: Tuberculosis-485.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 36ms/step
# Imagen: Tuberculosis-644.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 31ms/step
# Imagen: Tuberculosis-247.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 35ms/step
# Imagen: Tuberculosis-57.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 30ms/step
# Imagen: Tuberculosis-251.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 27ms/step
# Imagen: CHNCXR_0362_1.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 27ms/step
# Imagen: Tuberculosis-394.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 28ms/step
# Imagen: Tuberculosis-522.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 36ms/step
# Imagen: CHNCXR_0555_1.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 28ms/step
# Imagen: CHNCXR_0428_1.png, Carpeta Real: TUBERCULOSIS, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 27ms/step
# Imagen: person629_bacteria_2509.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 30ms/step
# Imagen: person724_virus_1343.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 36ms/step
# Imagen: person16_bacteria_55.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 39ms/step
# Imagen: person421_virus_866.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 34ms/step
# Imagen: person661_virus_1245.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 27ms/step
# Imagen: person145_virus_295.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 27ms/step
# Imagen: person51_bacteria_248.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 29ms/step
# Imagen: person707_virus_1305.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 27ms/step
# Imagen: person485_bacteria_2049.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 32ms/step
# Imagen: person1124_virus_1851.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 27ms/step
# Imagen: person623_virus_1197.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 28ms/step
# Imagen: person1133_virus_1865.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 28ms/step
# Imagen: person309_virus_631.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 27ms/step
# Imagen: person569_virus_1110.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 50ms/step
# Imagen: person413_virus_844.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 49ms/step
# Imagen: person326_bacteria_1505.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 51ms/step
# Imagen: person134_virus_268.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 49ms/step
# Imagen: person1048_virus_1744.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 32ms/step
# Imagen: person441_virus_896.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 36ms/step
# Imagen: person617_bacteria_2488.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 33ms/step
# Imagen: person26_bacteria_122.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 27ms/step
# Imagen: person1029_virus_1721.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 61ms/step
# Imagen: person347_bacteria_1597.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 29ms/step
# Imagen: person258_bacteria_1208.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 27ms/step
# Imagen: person749_bacteria_2652.jpeg, Carpeta Real: PNEUMONIA, Carpeta Predicha: NORMAL
# 1/1 [==============================] - 0s 27ms/step
# Imagen: IM-0483-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 28ms/step
# Imagen: NORMAL2-IM-0935-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 28ms/step
# Imagen: NORMAL2-IM-0454-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 29ms/step
# Imagen: NORMAL2-IM-0480-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 39ms/step
# Imagen: IM-0357-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 34ms/step
# Imagen: IM-0423-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 29ms/step
# Imagen: IM-0545-0001-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 44ms/step
# Imagen: NORMAL2-IM-0427-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 35ms/step
# Imagen: IM-0400-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 30ms/step
# Imagen: NORMAL2-IM-0493-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 34ms/step
# Imagen: NORMAL2-IM-0671-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 60ms/step
# Imagen: NORMAL2-IM-1326-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 34ms/step
# Imagen: IM-0312-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 79ms/step
# Imagen: NORMAL2-IM-1041-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 28ms/step
# Imagen: NORMAL2-IM-1357-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 29ms/step
# Imagen: NORMAL2-IM-1214-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 34ms/step
# Imagen: IM-0612-0001-0002.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 44ms/step
# Imagen: NORMAL2-IM-1291-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 40ms/step
# Imagen: IM-0665-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 36ms/step
# Imagen: NORMAL2-IM-1148-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 32ms/step
# Imagen: IM-0551-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 30ms/step
# Imagen: NORMAL2-IM-1236-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 29ms/step
# Imagen: NORMAL2-IM-1345-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 27ms/step
# Imagen: NORMAL2-IM-1130-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 29ms/step
# Imagen: NORMAL2-IM-1271-0001.jpeg, Carpeta Real: NORMAL, Carpeta Predicha: PNEUMONIA
# 1/1 [==============================] - 0s 27ms/step
# Imagen: COVID-19 (354).jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 36ms/step
# Imagen: COVID19(193).jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 29ms/step
# Imagen: COVID-19 (501).jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 27ms/step
# Imagen: COVID-19 (446).jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 28ms/step
# Imagen: 131.jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 28ms/step
# Imagen: COVID19(501).jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 28ms/step
# Imagen: 489.png, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 28ms/step
# Imagen: 147.png, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 31ms/step
# Imagen: COVID-19 (282).jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 28ms/step
# Imagen: COVID19(106).jpg, Carpeta Real: COVID, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 29ms/step
# Imagen: 238.png, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 28ms/step
# Imagen: 020.jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 28ms/step
# Imagen: COVID19(423).jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 27ms/step
# Imagen: 442.png, Carpeta Real: COVID, Carpeta Predicha: COVID
# 1/1 [==============================] - 0s 28ms/step
# Imagen: 681.jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 30ms/step
# Imagen: COVID-19 (232).jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 29ms/step
# Imagen: COVID-19 (26).jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 28ms/step
# Imagen: COVID-19 (509).jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 31ms/step
# Imagen: 435.jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 26ms/step
# Imagen: COVID19(156).jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 28ms/step
# Imagen: COVID-19 (653).jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 27ms/step
# Imagen: COVID-19 (404).jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 30ms/step
# Imagen: COVID-19 (709).jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 29ms/step
# Imagen: COVID19(99).jpg, Carpeta Real: COVID, Carpeta Predicha: TUBERCULOSIS
# 1/1 [==============================] - 0s 29ms/step
# Imagen: c3829ecb.png, Carpeta Real: COVID, Carpeta Predicha: COVID
