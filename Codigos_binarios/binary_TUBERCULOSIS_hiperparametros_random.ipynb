# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.regularizers import l2
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import random
from tensorflow.keras.preprocessing import image
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import keras_tuner
# Out:
# WARNING:tensorflow:From d:\Users\krisz\miniconda3\envs\clase\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Directorios de datos
directorio_entrenamiento = 'C:/Users/krisz/Desktop/LungsXray-FP-main/LungsXray-FP-main/data/Conjuntos_TUBERCULOSIS/entrenamiento'
directorio_validacion = 'C:/Users/krisz/Desktop/LungsXray-FP-main/LungsXray-FP-main/data/Conjuntos_TUBERCULOSIS/validacion'
directorio_testeo = 'C:/Users/krisz/Desktop/LungsXray-FP-main/LungsXray-FP-main/data/Conjuntos_TUBERCULOSIS/testeo'

# %%
# Configurar parámetros
batch_size = 32
img_height = 150
img_width = 150

# Preprocesamiento de datos y aumento de datos para entrenamiento
train_data_gen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=15,  # Nueva técnica: rotación
    width_shift_range=0.1,  # Nueva técnica: desplazamiento horizontal
    height_shift_range=0.1,  # Nueva técnica: desplazamiento vertical
)

# Preprocesamiento de datos para validación y prueba (sin aumento)
val_test_data_gen = ImageDataGenerator(rescale=1./255)

# Generadores de datos para entrenamiento, validación y prueba
train_generator = train_data_gen.flow_from_directory(
    directorio_entrenamiento,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',  # Usamos 'binary' porque ya tenemos las etiquetas en los nombres de los archivos
    shuffle=True
)

val_generator = val_test_data_gen.flow_from_directory(
    directorio_validacion,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False  # No es necesario barajar el conjunto de validación
)

test_generator = val_test_data_gen.flow_from_directory(
    directorio_testeo,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False  # No es necesario barajar el conjunto de prueba
)
# Out:
# Found 1399 images belonging to 2 classes.
# Found 299 images belonging to 2 classes.
# Found 301 images belonging to 2 classes.

# %%
def build_model(hp):
    model = Sequential([
        Conv2D(
            filters=hp.Int('conv_1_filter', min_value=32, max_value=128, step=32),
            kernel_size=hp.Choice('conv_1_kernel', values = [3,5]),
            activation='relu',
            input_shape=(img_height, img_width, 3),
            kernel_regularizer=l2(0.01)
        ),
        MaxPooling2D((2, 2)),    
        Conv2D(
            filters=hp.Int('conv_2_filter', min_value=32, max_value=64, step=32),
            kernel_size=hp.Choice('conv_2_kernel', values = [3,5]),
            activation='relu',
            kernel_regularizer=l2(0.01)
        ),
        MaxPooling2D((2, 2)),    
        Conv2D(
            filters=hp.Int('conv_3_filter', min_value=64, max_value=128, step=32),
            kernel_size=hp.Choice('conv_3_kernel', values = [3,5]),
            activation='relu',
            kernel_regularizer=l2(0.01)
        ),
        MaxPooling2D((2, 2)),    
        Flatten(),
        Dense(
            units=hp.Int('dense_1_units', min_value=32, max_value=256, step=32),
            activation='relu',
            kernel_regularizer=l2(0.01)
        ),
        Dropout(hp.Float('dropout', min_value=0.0, max_value=0.5, step=0.1)),
        Dense(1, activation='sigmoid')
    ])
    

    # Compilar el modelo con la tasa de aprendizaje
    model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])
    
    return model

# %%
tuner = keras_tuner.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,
    directory='Tuberculosis_random',
    project_name="RandomSearch"
)
# Out:
# WARNING:tensorflow:From d:\Users\krisz\miniconda3\envs\clase\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\krisz\miniconda3\envs\clase\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From d:\Users\krisz\miniconda3\envs\clase\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Implementar EarlyStopping para detener el entrenamiento si no mejora la métrica de validación
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %%
for trial in range(10):
    tuner.search(train_generator, epochs=10, validation_data=val_generator,callbacks=[early_stopping])
    tf.keras.backend.clear_session()
# Out:
# Trial 10 Complete [00h 02m 48s]
# val_accuracy: 0.8963210582733154
#
# Best val_accuracy So Far: 0.909699022769928
# Total elapsed time: 00h 30m 41s

# %%
# Obtener el mejor modelo
best_model = tuner.get_best_models(num_models=1)[0]

# %%
# Obtener los mejores hiperparámetros
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]
print(best_hyperparameters.values)
# Out:
# {'conv_1_filter': 64, 'conv_1_kernel': 3, 'conv_2_filter': 64, 'conv_2_kernel': 3, 'conv_3_filter': 96, 'conv_3_kernel': 3, 'dense_1_units': 224, 'dropout': 0.0}

# %%
# Implementar EarlyStopping para detener el entrenamiento si no mejora la métrica de validación
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Implementar ModelCheckpoint para guardar el mejor modelo durante el entrenamiento
model_checkpoint = ModelCheckpoint('modelo_Tuberculosis_hiperparametros_randomsearch.h5', save_best_only=True)

# %%
# Entrenar el mejor modelo con los datos del generador, agregar regularización y ajustar pesos de clase
history = best_model.fit(
    train_generator,
    epochs=50,  # Ajusta según sea necesario
    validation_data=val_generator,
    callbacks=[early_stopping, model_checkpoint],
    class_weight=None  # Puedes ajustar esto si encuentras desequilibrios en la distribución de clases
)
# Out:
# Epoch 1/50
# 44/44 [==============================] - 14s 292ms/step - loss: 0.5634 - accuracy: 0.8227 - val_loss: 0.5275 - val_accuracy: 0.8829
# Epoch 2/50
# d:\Users\krisz\miniconda3\envs\clase\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 44/44 [==============================] - 12s 282ms/step - loss: 0.5404 - accuracy: 0.8320 - val_loss: 0.4838 - val_accuracy: 0.8796
# Epoch 3/50
# 44/44 [==============================] - 12s 282ms/step - loss: 0.5386 - accuracy: 0.8199 - val_loss: 0.5069 - val_accuracy: 0.8562
# Epoch 4/50
# 44/44 [==============================] - 13s 291ms/step - loss: 0.5145 - accuracy: 0.8449 - val_loss: 0.4475 - val_accuracy: 0.8528
# Epoch 5/50
# 44/44 [==============================] - 13s 286ms/step - loss: 0.5389 - accuracy: 0.8270 - val_loss: 0.4297 - val_accuracy: 0.8662
# Epoch 6/50
# 44/44 [==============================] - 13s 285ms/step - loss: 0.4701 - accuracy: 0.8556 - val_loss: 0.5185 - val_accuracy: 0.8227
# Epoch 7/50
# 44/44 [==============================] - 12s 275ms/step - loss: 0.4846 - accuracy: 0.8492 - val_loss: 0.4371 - val_accuracy: 0.8896
# Epoch 8/50
# 44/44 [==============================] - 12s 279ms/step - loss: 0.4663 - accuracy: 0.8585 - val_loss: 0.3985 - val_accuracy: 0.8930
# Epoch 9/50
# 44/44 [==============================] - 12s 279ms/step - loss: 0.4674 - accuracy: 0.8506 - val_loss: 0.4046 - val_accuracy: 0.8796
# Epoch 10/50
# 44/44 [==============================] - 12s 278ms/step - loss: 0.4488 - accuracy: 0.8549 - val_loss: 0.3943 - val_accuracy: 0.9030
# Epoch 11/50
# 44/44 [==============================] - 12s 279ms/step - loss: 0.4592 - accuracy: 0.8470 - val_loss: 0.3850 - val_accuracy: 0.9064
# Epoch 12/50
# 44/44 [==============================] - 12s 277ms/step - loss: 0.4487 - accuracy: 0.8535 - val_loss: 0.3875 - val_accuracy: 0.8963
# Epoch 13/50
# 44/44 [==============================] - 12s 280ms/step - loss: 0.4241 - accuracy: 0.8713 - val_loss: 0.3816 - val_accuracy: 0.9064
# Epoch 14/50
# 44/44 [==============================] - 12s 281ms/step - loss: 0.4124 - accuracy: 0.8635 - val_loss: 0.3692 - val_accuracy: 0.8896
# Epoch 15/50
# 44/44 [==============================] - 12s 280ms/step - loss: 0.4277 - accuracy: 0.8656 - val_loss: 0.3911 - val_accuracy: 0.8796
# Epoch 16/50
# 44/44 [==============================] - 13s 290ms/step - loss: 0.4388 - accuracy: 0.8606 - val_loss: 0.3643 - val_accuracy: 0.8763
# Epoch 17/50
# 44/44 [==============================] - 12s 276ms/step - loss: 0.4388 - accuracy: 0.8628 - val_loss: 0.3652 - val_accuracy: 0.9030
# Epoch 18/50
# 44/44 [==============================] - 12s 283ms/step - loss: 0.4159 - accuracy: 0.8649 - val_loss: 0.3565 - val_accuracy: 0.9064
# Epoch 19/50
# 44/44 [==============================] - 12s 278ms/step - loss: 0.3923 - accuracy: 0.8735 - val_loss: 0.3548 - val_accuracy: 0.9097
# Epoch 20/50
# 44/44 [==============================] - 12s 279ms/step - loss: 0.4101 - accuracy: 0.8699 - val_loss: 0.3509 - val_accuracy: 0.9064
# Epoch 21/50
# 44/44 [==============================] - 12s 280ms/step - loss: 0.3937 - accuracy: 0.8721 - val_loss: 0.3349 - val_accuracy: 0.9064
# Epoch 22/50
# 44/44 [==============================] - 12s 279ms/step - loss: 0.4506 - accuracy: 0.8477 - val_loss: 0.3797 - val_accuracy: 0.8896
# Epoch 23/50
# 44/44 [==============================] - 12s 273ms/step - loss: 0.5156 - accuracy: 0.8449 - val_loss: 0.4134 - val_accuracy: 0.9097
# Epoch 24/50
# 44/44 [==============================] - 12s 279ms/step - loss: 0.4193 - accuracy: 0.8742 - val_loss: 0.3666 - val_accuracy: 0.9030
# Epoch 25/50
# 44/44 [==============================] - 12s 280ms/step - loss: 0.3941 - accuracy: 0.8713 - val_loss: 0.3319 - val_accuracy: 0.9164
# Epoch 26/50
# 44/44 [==============================] - 12s 280ms/step - loss: 0.3740 - accuracy: 0.8756 - val_loss: 0.3341 - val_accuracy: 0.9064
# Epoch 27/50
# 44/44 [==============================] - 12s 276ms/step - loss: 0.3921 - accuracy: 0.8785 - val_loss: 0.3516 - val_accuracy: 0.9030
# Epoch 28/50
# 44/44 [==============================] - 12s 281ms/step - loss: 0.3790 - accuracy: 0.8885 - val_loss: 0.3347 - val_accuracy: 0.8963
# Epoch 29/50
# 44/44 [==============================] - 12s 278ms/step - loss: 0.3731 - accuracy: 0.8921 - val_loss: 0.3185 - val_accuracy: 0.9130
# Epoch 30/50
# 44/44 [==============================] - 12s 277ms/step - loss: 0.3805 - accuracy: 0.8885 - val_loss: 0.3110 - val_accuracy: 0.9197
# Epoch 31/50
# 44/44 [==============================] - 12s 275ms/step - loss: 0.3843 - accuracy: 0.8778 - val_loss: 0.3078 - val_accuracy: 0.9097
# Epoch 32/50
# 44/44 [==============================] - 12s 279ms/step - loss: 0.3735 - accuracy: 0.8821 - val_loss: 0.3038 - val_accuracy: 0.9064
# Epoch 33/50
# 44/44 [==============================] - 13s 288ms/step - loss: 0.3595 - accuracy: 0.8892 - val_loss: 0.3264 - val_accuracy: 0.9030
# Epoch 34/50
# 44/44 [==============================] - 13s 287ms/step - loss: 0.3791 - accuracy: 0.8742 - val_loss: 0.3760 - val_accuracy: 0.8829
# Epoch 35/50
# 44/44 [==============================] - 12s 281ms/step - loss: 0.4145 - accuracy: 0.8628 - val_loss: 0.3227 - val_accuracy: 0.9197
# Epoch 36/50
# 44/44 [==============================] - 12s 279ms/step - loss: 0.3795 - accuracy: 0.8821 - val_loss: 0.3201 - val_accuracy: 0.8997
# Epoch 37/50
# 44/44 [==============================] - 12s 277ms/step - loss: 0.3758 - accuracy: 0.8821 - val_loss: 0.3274 - val_accuracy: 0.9097

# %%
# Visualizar el rendimiento del modelo
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Evaluar el modelo en el conjunto de prueba
test_loss, test_acc = best_model.evaluate(test_generator, verbose=2)
print('\nExactitud en el conjunto de prueba:', test_acc)

# Predicciones en el conjunto de prueba
y_pred = best_model.predict(test_generator)
y_pred_classes = (y_pred > 0.5).astype(int)

# Matriz de confusión
conf_mat = confusion_matrix(test_generator.classes, y_pred_classes)
plt.figure(figsize=(6, 6))
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=train_generator.class_indices,
            yticklabels=train_generator.class_indices)
plt.xlabel('Predicciones')
plt.ylabel('Etiquetas verdaderas')
plt.show()

# Informe de clasificación
print(classification_report(test_generator.classes, y_pred_classes))
# Out:
# 10/10 - 1s - loss: 0.2760 - accuracy: 0.9203 - 718ms/epoch - 72ms/step
#
# Exactitud en el conjunto de prueba: 0.920265793800354
# 10/10 [==============================] - 1s 67ms/step
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       150
#            1       0.95      0.89      0.92       151
#
#     accuracy                           0.92       301
#    macro avg       0.92      0.92      0.92       301
# weighted avg       0.92      0.92      0.92       301

# %%
modelo = load_model('C:/Users/krisz/Desktop/LungsXray-FP-main/LungsXray-FP-main/src/modelo_Tuberculosis_hiperparametros_randomsearch.h5')

# %%
# Función para mostrar imágenes con predicciones en una cuadrícula
def mostrar_imagenes_predicciones(modelo, directorio, num_imagenes_por_clase=25, columnas=5):
    clases = os.listdir(directorio)
    
    for clase in clases:
        ruta_clase = os.path.join(directorio, clase)
        imagenes = random.sample(os.listdir(ruta_clase), num_imagenes_por_clase)
        
        # Crear una cuadrícula de subgráficos
        fig, axs = plt.subplots(nrows=num_imagenes_por_clase//columnas, ncols=columnas, figsize=(15, 15))
        fig.suptitle(f'Carpeta: {clase}', fontsize=16)

        for i, imagen_nombre in enumerate(imagenes):
            imagen_path = os.path.join(ruta_clase, imagen_nombre)
            img = image.load_img(imagen_path, target_size=(img_height, img_width))
            img_array = image.img_to_array(img)
            img_array = np.expand_dims(img_array, axis=0)
            img_array /= 255.0  # Normalizar

            prediccion = modelo.predict(img_array)
            clase_predicha = 'Tuberculosis' if prediccion < 0.5 else 'RESTO'

            # Mostrar cada imagen en un subgráfico
            row = i // columnas
            col = i % columnas
            axs[row, col].imshow(img)
            axs[row, col].set_title(f'{clase_predicha}\nCarpeta: {clase}')
            axs[row, col].axis('off')

        plt.show()

# Ruta al directorio con subcarpetas de imágenes de prueba
ruta_directorio_prueba = 'C:/Users/krisz/Desktop/LungsXray-FP-main/LungsXray-FP-main/data/Conjuntos_TUBERCULOSIS/testeo'

# Llamar a la función para mostrar imágenes y predicciones en una cuadrícula
mostrar_imagenes_predicciones(modelo, ruta_directorio_prueba)
# Out:
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
